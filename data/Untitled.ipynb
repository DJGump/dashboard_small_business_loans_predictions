# %%
# %reload_ext nb_black

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sba_loans_cleaned3.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520954 entries, 0 to 520953
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   State               520954 non-null  object
#  1   BankState           520954 non-null  object
#  2   ApprovalFY          520954 non-null  int64
#  3   NoEmp               520954 non-null  int64
#  4   NewExist            520954 non-null  int64
#  5   RevLineCr           520421 non-null  float64
#  6   LowDoc              516749 non-null  float64
#  7   DisbursementGross   520954 non-null  float64
#  8   MIS_Status          520954 non-null  int64
#  9   twoDigNAICS         520954 non-null  int64
#  10  is_franchise        520954 non-null  float64
#  11  bank_out_of_state   520954 non-null  int64
#  12  Term_years          520954 non-null  float64
#  13  job_category        520954 non-null  float64
#  14  retained_category   520954 non-null  float64
#  15  UrbanRural_cleaned  514461 non-null  float64
#  16  Disbr_year          520954 non-null  int64
#  17  Disbr_Month_sin     520954 non-null  float64
#  18  Disbr_Month_cos     520954 non-null  float64
#  19  sba_pre_approv      520954 non-null  float64
#  20  percent_SBA         520954 non-null  float64
#  21  bank_size           520954 non-null  float64
#  22  Appv_Month_sin      520954 non-null  float64
#  23  Appv_Month_cos      520954 non-null  float64
# dtypes: float64(15), int64(7), object(2)
# memory usage: 95.4+ MB

# %%
df.columns.to_list()
# Out:
# ['State',
#  'BankState',
#  'ApprovalFY',
#  'NoEmp',
#  'NewExist',
#  'RevLineCr',
#  'LowDoc',
#  'DisbursementGross',
#  'MIS_Status',
#  'twoDigNAICS',
#  'is_franchise',
#  'bank_out_of_state',
#  'Term_years',
#  'job_category',
#  'retained_category',
#  'UrbanRural_cleaned',
#  'Disbr_year',
#  'Disbr_Month_sin',
#  'Disbr_Month_cos',
#  'sba_pre_approv',
#  'percent_SBA',
#  'bank_size',
#  'Appv_Month_sin',
#  'Appv_Month_cos']

# %%
rename_dict = {
    "State": "State",
    "BankState": "Bank State",
    "ApprovalFY": "Approval Fiscal Year",
    "NoEmp": "Number of Employees",
    "NewExist": "New or Existing Business Status",
    "RevLineCr": "Revolving Line of Credit Status",
    "LowDoc": "Low Documentation Approved Status",
    "DisbursementGross": "Disbursement (Gross)",
    "MIS_Status": "MIS_Status (Outcome)",
    "twoDigNAICS": "Two Digit NAICS Industry Code",
    "is_franchise": "Franchise Status",
    "bank_out_of_state": "Bank Out of State Status",
    "Term_years": "Loan Term (Years)",
    "job_category": "Jobs Created Rank",
    "retained_category": "Jobs Retained Rank",
    "UrbanRural_cleaned": "Urban or Rural Status",
    "Disbr_year": "Year of Disbursement",
    "Disbr_Month_sin": "Disbr_Month_sin",
    "Disbr_Month_cos": "Disbr_Month_cos",
    "sba_pre_approv": "SBA Pre-Approval",
    "percent_SBA": "Loan Percentage SBA Committed",
    "bank_size": "Bank Size Rank",
    "Appv_Month_sin": "Appv_Month_sin",
    "Appv_Month_cos": "Appv_Month_cos",
}

# %%
df.select_dtypes(include="number").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520954 entries, 0 to 520953
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ApprovalFY          520954 non-null  int64
#  1   NoEmp               520954 non-null  int64
#  2   NewExist            520954 non-null  int64
#  3   RevLineCr           520421 non-null  float64
#  4   LowDoc              516749 non-null  float64
#  5   DisbursementGross   520954 non-null  float64
#  6   MIS_Status          520954 non-null  int64
#  7   twoDigNAICS         520954 non-null  int64
#  8   is_franchise        520954 non-null  float64
#  9   bank_out_of_state   520954 non-null  int64
#  10  Term_years          520954 non-null  float64
#  11  job_category        520954 non-null  float64
#  12  retained_category   520954 non-null  float64
#  13  UrbanRural_cleaned  514461 non-null  float64
#  14  Disbr_year          520954 non-null  int64
#  15  Disbr_Month_sin     520954 non-null  float64
#  16  Disbr_Month_cos     520954 non-null  float64
#  17  sba_pre_approv      520954 non-null  float64
#  18  percent_SBA         520954 non-null  float64
#  19  bank_size           520954 non-null  float64
#  20  Appv_Month_sin      520954 non-null  float64
#  21  Appv_Month_cos      520954 non-null  float64
# dtypes: float64(15), int64(7)
# memory usage: 87.4 MB

# %%
df.rename(columns=rename_dict)
# Out:
#        State Bank State  Approval Fiscal Year  Number of Employees  \
# 0         NC         MN                  2006                    2
# 1         AR         MS                  2006                    7
# 2         CA         SD                  2006                   18
# 3         FL         FL                  2006                    4
# 4         LA         LA                  2006                    3
# ...      ...        ...                   ...                  ...
# 520949    CO         IL                  2006                    2
# 520950    AZ         WI                  2006                    2
# 520951    NV         NV                  2006                   20
# 520952    AZ         AL                  2006                    3
# 520953    IL         IL                  2006                   10
#
#         New or Existing Business Status  Revolving Line of Credit Status  \
# 0                                     1                              0.0
# 1                                     0                              0.0
# 2                                     1                              1.0
# 3                                     0                              1.0
# 4                                     0                              0.0
# ...                                 ...                              ...
# 520949                                0                              1.0
# 520950                                1                              0.0
# 520951                                0                              0.0
# 520952                                0                              1.0
# 520953                                0                              0.0
#
#         Low Documentation Approved Status  Disbursement (Gross)  \
# 0                                     0.0              253400.0
# 1                                     0.0              137300.0
# 2                                     0.0              438541.0
# 3                                     0.0               51440.0
# 4                                     0.0               50000.0
# ...                                   ...                   ...
# 520949                                0.0               30000.0
# 520950                                0.0              170000.0
# 520951                                0.0              509000.0
# 520952                                0.0               15635.0
# 520953                                0.0             1038000.0
#
#         MIS_Status (Outcome)  Two Digit NAICS Industry Code  ...  \
# 0                          0                             44  ...
# 1                          0                             72  ...
# 2                          0                             61  ...
# 3                          0                             23  ...
# 4                          0                             53  ...
# ...                      ...                            ...  ...
# 520949                     0                             61  ...
# 520950                     1                             81  ...
# 520951                     0                             23  ...
# 520952                     0                             51  ...
# 520953                     0                             72  ...
#
#         Jobs Retained Rank  Urban or Rural Status  Year of Disbursement  \
# 0                      0.0                    0.0                  2006
# 1                      0.0                    0.0                  2006
# 2                      2.0                    0.0                  2006
# 3                      1.0                    0.0                  2006
# 4                      0.0                    0.0                  2006
# ...                    ...                    ...                   ...
# 520949                 1.0                    1.0                  2006
# 520950                 1.0                    0.0                  2006
# 520951                 0.0                    0.0                  2007
# 520952                 1.0                    0.0                  2006
# 520953                 1.0                    0.0                  2006
#
#         Disbr_Month_sin  Disbr_Month_cos  SBA Pre-Approval  \
# 0              0.866025     5.000000e-01               1.0
# 1              1.000000     6.123234e-17               1.0
# 2              0.500000     8.660254e-01               1.0
# 3              0.500000     8.660254e-01               1.0
# 4              0.866025    -5.000000e-01               1.0
# ...                 ...              ...               ...
# 520949         0.500000     8.660254e-01               1.0
# 520950         0.500000     8.660254e-01               1.0
# 520951         0.866025    -5.000000e-01               1.0
# 520952         0.500000     8.660254e-01               1.0
# 520953         1.000000     6.123234e-17               1.0
#
#         Loan Percentage SBA Committed  Bank Size Rank  Appv_Month_sin  \
# 0                                0.75             1.0             0.5
# 1                                0.85             0.0             0.5
# 2                                0.50             2.0             0.5
# 3                                0.50             2.0             0.5
# 4                                0.85             0.0             0.5
# ...                               ...             ...             ...
# 520949                           0.50             2.0             0.5
# 520950                           0.75             1.0             0.5
# 520951                           1.00             1.0             0.5
# 520952                           0.50             2.0             0.5
# 520953                           1.00             1.0             0.5
#
#         Appv_Month_cos
# 0             0.866025
# 1             0.866025
# 2             0.866025
# 3             0.866025
# 4             0.866025
# ...                ...
# 520949        0.866025
# 520950        0.866025
# 520951        0.866025
# 520952        0.866025
# 520953        0.866025
#
# [520954 rows x 24 columns]
