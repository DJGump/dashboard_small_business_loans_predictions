# %%
import pandas as pd

# read in cleaned loan data
df = pd.read_csv('sba_loans_cleaned3.csv')

rename_dict = {
    "State": "State",
    "BankState": "Bank State",
    "ApprovalFY": "Approval Fiscal Year",
    "NoEmp": "Number of Employees",
    "NewExist": "New or Existing Business Status",
    "RevLineCr": "Revolving Line of Credit Status",
    "LowDoc": "Low Documentation Approved Status",
    "DisbursementGross": "Disbursement (Gross)",
    "MIS_Status": "MIS_Status (Outcome)",
    "twoDigNAICS": "Two Digit NAICS Industry Code",
    "is_franchise": "Franchise Status",
    "bank_out_of_state": "Bank Out of State Status",
    "Term_years": "Loan Term (Years)",
    "job_category": "Jobs Created Rank",
    "retained_category": "Jobs Retained Rank",
    "UrbanRural_cleaned": "Urban or Rural Status",
    "Disbr_year": "Year of Disbursement",
    "Disbr_Month_sin": "Disbr_Month_sin",
    "Disbr_Month_cos": "Disbr_Month_cos",
    "sba_pre_approv": "SBA Pre-Approval",
    "percent_SBA": "Loan Percentage SBA Committed",
    "bank_size": "Bank Size Rank",
    "Appv_Month_sin": "Appv_Month_sin",
    "Appv_Month_cos": "Appv_Month_cos",
}

df.rename(columns=rename_dict, inplace=True)
df = df.round(decimals=2)

# %%
df.sample(1000).to_dict('records')
# Out:
# [{'State': 'NC',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': nan,
#   'Disbursement (Gross)': 40000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 53,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 3.5,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'CA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 5.08,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'NH',
#   'Bank State': 'NH',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 73,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 133000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 33,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.75,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'PA',
#   'Bank State': 'NY',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 15,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 5.25,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'WA',
#   'Bank State': 'OH',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 133842.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'UT',
#   'Bank State': 'UT',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 95346.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 33,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'OH',
#   'Bank State': 'DE',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 61450.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 2.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 200000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': -1.0},
#  {'State': 'TX',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50640.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'AR',
#   'Bank State': 'AR',
#   'Approval Fiscal Year': 2010,
#   'Number of Employees': 40,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 31300.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 1.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 4.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2010,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.9,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'PA',
#   'Bank State': 'PA',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 6,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 14650.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 3.92,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'LA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 5000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'LA',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2002,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 38397.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'NY',
#   'Bank State': 'NY',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 150000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 45,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 10000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 62,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 3.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'VA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'TX',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 5000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 5.75,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'NY',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 16,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 78716.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'WI',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 390000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 9.08,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'CA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 89231.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 62,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'MA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 25000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 2.58,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': -1.0},
#  {'State': 'NY',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 58561.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'CA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 3.33,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'DC',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 7,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'AZ',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 45000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 5.92,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'OH',
#   'Bank State': 'IN',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 6,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 110893.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'WI',
#   'Bank State': 'WI',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 125000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 45,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 0.92,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': nan,
#   'Disbursement (Gross)': 210000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': nan,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'GA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 25000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'OH',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 10,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 75000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 56,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.42,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'PA',
#   'Bank State': 'PA',
#   'Approval Fiscal Year': 2002,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 35000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'ME',
#   'Bank State': 'ME',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 11,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 490000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': 1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'AZ',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 8,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 448500.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 25.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'PA',
#   'Bank State': 'DE',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 15500.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 0.33,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'IA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 7,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.92,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'MN',
#   'Bank State': 'MN',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 53000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 0.42,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2002,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 257500.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 42,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 10.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'MA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 35000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 71,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'CA',
#   'Bank State': 'NY',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 100725.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 0.17,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'PA',
#   'Bank State': 'DE',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 29976.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 48,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.25,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': -1.0},
#  {'State': 'UT',
#   'Bank State': 'UT',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 221202.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.83,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'FL',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 171647.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': -1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'AZ',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 5,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': nan,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 2.25,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'FL',
#   'Bank State': 'AL',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 0,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 600000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 10.0,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': 1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': -1.0},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 27,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': nan,
#   'Disbursement (Gross)': 163118.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.67,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': nan,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'FL',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'IL',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 13,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 696000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 1.0,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'VA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2009,
#   'Number of Employees': 45,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 240000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 5.08,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'WI',
#   'Bank State': 'WI',
#   'Approval Fiscal Year': 2010,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 221000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 11,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 8.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2010,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 0.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'NY',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 6,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 50000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 2.75,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': 1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'CA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 15000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'ID',
#   'Bank State': 'ID',
#   'Approval Fiscal Year': 2002,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 1.0,
#   'Disbursement (Gross)': 107152.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 45,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 10.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 30,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 2000000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 1.75,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2008,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': -1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'TX',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 5000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'GA',
#   'Bank State': 'GA',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 3,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 157500.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 0.83,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'CA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 59494.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 45,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 5.25,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 10,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 361000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 1.0,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'PA',
#   'Bank State': 'RI',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 4,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 142777.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 0.5,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 150000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 10.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'DC',
#   'Bank State': 'SC',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 7,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 485000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 25.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2002,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 20,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 179880.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 56,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 1.0,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': 0.87},
#  {'State': 'WA',
#   'Bank State': 'OH',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 30000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 4.08,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'MA',
#   'Bank State': 'RI',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 45,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 5000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 56,
#   'Franchise Status': 1.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'WI',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2010,
#   'Number of Employees': 75,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 132020.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 71,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2009,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'AZ',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 17,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 68645.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'CA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2008,
#   'Number of Employees': 2,
# ...
#   'Disbursement (Gross)': 79660.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 3.83,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'FL',
#   'Bank State': 'NY',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 45000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 31,
#   'Franchise Status': 1.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'NJ',
#   'Bank State': 'NJ',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 5,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 268000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'WA',
#   'Bank State': 'WA',
#   'Approval Fiscal Year': 2010,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 120000.0,
#   'MIS_Status (Outcome)': 1,
#   'Two Digit NAICS Industry Code': 44,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2010,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': 1.0,
#   'SBA Pre-Approval': 0.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'PA',
#   'Bank State': 'RI',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 8,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 6888.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'LA',
#   'Bank State': 'FL',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 25000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.85,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'MA',
#   'Bank State': 'RI',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 10000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 56,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2007,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': -1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'GA',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2003,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 10000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'AR',
#   'Bank State': 'AR',
#   'Approval Fiscal Year': 2011,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 11600.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 11,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 10.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2011,
#   'Disbr_Month_sin': 0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': 1.0},
#  {'State': 'MD',
#   'Bank State': 'MD',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 45953.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2011,
#   'Number of Employees': 22,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 295000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 23,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 1.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2012,
#   'Disbr_Month_sin': 1.0,
#   'Disbr_Month_cos': 0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 0.0,
#   'Appv_Month_sin': 0.0,
#   'Appv_Month_cos': -1.0},
#  {'State': 'VA',
#   'Bank State': 'VA',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 23,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 1000000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 1.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 2.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 1.0,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'SD',
#   'Bank State': 'MN',
#   'Approval Fiscal Year': 2007,
#   'Number of Employees': 8,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 700000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 20.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': 0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'MA',
#   'Bank State': 'RI',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 57549.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'OK',
#   'Bank State': 'IL',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 6,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 321137.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 0.87,
#   'Appv_Month_cos': 0.5},
#  {'State': 'KS',
#   'Bank State': 'KS',
#   'Approval Fiscal Year': 2009,
#   'Number of Employees': 40,
#   'New or Existing Business Status': 1,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 350000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 1.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2009,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': -1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': 0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'CA',
#   'Bank State': 'CA',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 7500.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 61,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 3.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': 0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': 1.0,
#   'Appv_Month_cos': 0.0},
#  {'State': 'WV',
#   'Bank State': 'NC',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 6,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 605000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 54,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 14.0,
#   'Jobs Created Rank': 1.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2004,
#   'Disbr_Month_sin': 0.0,
#   'Disbr_Month_cos': 1.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'PA',
#   'Bank State': 'SD',
#   'Approval Fiscal Year': 2005,
#   'Number of Employees': 2,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 428800.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 33,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 25.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2005,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': -0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'ID',
#   'Bank State': 'UT',
#   'Approval Fiscal Year': 2006,
#   'Number of Employees': 18,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 99868.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 31,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 0,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 2.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2006,
#   'Disbr_Month_sin': -0.5,
#   'Disbr_Month_cos': -0.87,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -0.5,
#   'Appv_Month_cos': -0.87},
#  {'State': 'NH',
#   'Bank State': 'NH',
#   'Approval Fiscal Year': 2004,
#   'Number of Employees': 1,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 1.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 70100.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 81,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 7.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 1.0,
#   'Urban or Rural Status': 1.0,
#   'Year of Disbursement': 2003,
#   'Disbr_Month_sin': -0.87,
#   'Disbr_Month_cos': 0.5,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.5,
#   'Bank Size Rank': 2.0,
#   'Appv_Month_sin': -1.0,
#   'Appv_Month_cos': -0.0},
#  {'State': 'TX',
#   'Bank State': 'TX',
#   'Approval Fiscal Year': 2001,
#   'Number of Employees': 18,
#   'New or Existing Business Status': 0,
#   'Revolving Line of Credit Status': 0.0,
#   'Low Documentation Approved Status': 0.0,
#   'Disbursement (Gross)': 845000.0,
#   'MIS_Status (Outcome)': 0,
#   'Two Digit NAICS Industry Code': 72,
#   'Franchise Status': 0.0,
#   'Bank Out of State Status': 1,
#   'Loan Term (Years)': 25.0,
#   'Jobs Created Rank': 0.0,
#   'Jobs Retained Rank': 0.0,
#   'Urban or Rural Status': 0.0,
#   'Year of Disbursement': 2001,
#   'Disbr_Month_sin': -1.0,
#   'Disbr_Month_cos': -0.0,
#   'SBA Pre-Approval': 1.0,
#   'Loan Percentage SBA Committed': 0.75,
#   'Bank Size Rank': 1.0,
#   'Appv_Month_sin': -0.87,
#   'Appv_Month_cos': -0.5}]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520954 entries, 0 to 520953
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   State                              520954 non-null  object
#  1   Bank State                         520954 non-null  object
#  2   Approval Fiscal Year               520954 non-null  int64
#  3   Number of Employees                520954 non-null  int64
#  4   New or Existing Business Status    520954 non-null  int64
#  5   Revolving Line of Credit Status    520421 non-null  float64
#  6   Low Documentation Approved Status  516749 non-null  float64
#  7   Disbursement (Gross)               520954 non-null  float64
#  8   MIS_Status (Outcome)               520954 non-null  int64
#  9   Two Digit NAICS Industry Code      520954 non-null  int64
#  10  Franchise Status                   520954 non-null  float64
#  11  Bank Out of State Status           520954 non-null  int64
#  12  Loan Term (Years)                  520954 non-null  float64
#  13  Jobs Created Rank                  520954 non-null  float64
#  14  Jobs Retained Rank                 520954 non-null  float64
#  15  Urban or Rural Status              514461 non-null  float64
#  16  Year of Disbursement               520954 non-null  int64
#  17  Disbr_Month_sin                    520954 non-null  float64
#  18  Disbr_Month_cos                    520954 non-null  float64
#  19  SBA Pre-Approval                   520954 non-null  float64
#  20  Loan Percentage SBA Committed      520954 non-null  float64
#  21  Bank Size Rank                     520954 non-null  float64
#  22  Appv_Month_sin                     520954 non-null  float64
#  23  Appv_Month_cos                     520954 non-null  float64
# dtypes: float64(15), int64(7), object(2)
# memory usage: 95.4+ MB
